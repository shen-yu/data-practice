# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.rcParams['font.size']= 16

data=pd.read_csv('./spotify.csv',index_col="Date")
data2=pd.read_csv('./insurance.csv')
df=data.tail()

plt.figure(figsize=(10,6))

sns.lineplot(data=df['Shape of You'], label="shape")
sns.lineplot(data=df['Despacito'], label="Despacito")

list(df.columns)
# Out:
# ['Shape of You',
#  'Despacito',
#  'Something Just Like This',
#  'HUMBLE.',
#  'Unforgettable']

# %%
data2.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df2=data2
plt.figure(figsize=(10,6))
sns.lmplot(x="bmi",y='charges',hue='smoker',data=df2)
