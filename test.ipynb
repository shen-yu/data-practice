# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import akshare as ak

s = pd.Series([1, 3, 5, np.nan, 6, 8])
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
dates = pd.date_range('20130101', periods=6)
df = pd.DataFrame(np.random.randn(6, 4), index=dates, columns=list('ABCD'))
df
# Out:
#                    A         B         C         D
# 2013-01-01 -0.631073 -1.404494  0.668034  0.561799
# 2013-01-02  0.468488  0.927970  0.428934  0.611646
# 2013-01-03 -1.144511  1.645947 -0.368707  0.512882
# 2013-01-04  0.283131  1.227034  1.041607  1.041649
# 2013-01-05 -1.386451  0.110062  0.373916  0.065415
# 2013-01-06 -0.355165  0.070093 -0.903898 -0.291518

# %%
df[(df.A>=0.1)&(df.D>1)]
# Out:
#                   A         B         C         D
# 2013-01-03  0.16325  0.721555  0.230448  1.167485

# %%
df.sort_values(["A"],ascending=False)
# Out:
#                    A         B         C         D
# 2013-01-05  0.669338 -1.348690 -1.415242 -0.069145
# 2013-01-03  0.163250  0.721555  0.230448  1.167485
# 2013-01-04 -0.149668 -0.296662 -2.091106 -1.247055
# 2013-01-01 -0.196632 -0.326028 -0.560217 -0.314510
# 2013-01-06 -0.548258  0.852436 -0.276355 -0.900420
# 2013-01-02 -1.236802  0.237034  0.348477 -0.168971

# %%
# 疫情数据
covid_19_163_data=ak.covid_19_163(indicator="世界历史累计数据")
covid_19_163_data.loc['日本']
# Out:
# 数据更新时间: 2020-04-06 09:14:34
# confirm    4535.0
# suspect       0.0
# heal       1133.0
# dead        104.0
# severe        0.0
# input         NaN
# Name: 日本, dtype: float64

# %%
plt.plot([1,2,3],[2,4,8])
plt.show()
